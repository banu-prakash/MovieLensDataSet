# %% [markdown]
# # Analysis of the KNNBasic algorithm
#
# In this notebook, we will run a basic neighborhood algorithm on the movielens dataset, dump the results, and use pandas to make some data analysis.

# %%
from __future__ import (absolute_import, division, print_function,             
                        unicode_literals)                                      
import pickle
import os

import pandas as pd

from surprise import KNNWithMeans
from surprise import Dataset                                                     
from surprise import Reader                                                      
from surprise import dump
from surprise.accuracy import rmse

# %%
# Path Names for inserting TRAIN and TEST files
train_file = os.path.expanduser('~') + '/Downloads/ml-100k/u1.base'
test_file = os.path.expanduser('~') + '/Downloads/ml-100k/u1.test'
)
# Forming a Dataset with training and testing
data = Dataset.load_from_file([(train_file, test_file)], Reader('ml-100k')
print(data)
# Out:
# <surprise.dataset.DatasetUserFolds object at 0x7fec51acae80>

# %%
# Using Surprise Algorithm : KNNWithmeans()
algo = KNNWithMeans()                                                       
# Predicting VAlue
for trainset, testset in data.folds(): 
    algo.train(trainset) 
    predictions = algo.test(testset)
    rmse(predictions)
                                                                               
    dump('./dump_file', predictions, trainset, algo)

# %%
pd.DataFrame(predictions)
# Out:
#        uid   iid  r_ui       est                                    details
# 0        1     6   5.0  3.684493  {'actual_k': 20, 'was_impossible': False}
# 1        1    10   3.0  3.830113  {'actual_k': 40, 'was_impossible': False}
# 2        1    12   5.0  4.413642  {'actual_k': 40, 'was_impossible': False}
# 3        1    14   5.0  4.156297  {'actual_k': 40, 'was_impossible': False}
# 4        1    17   3.0  3.504539  {'actual_k': 40, 'was_impossible': False}
# 5        1    20   4.0  3.519806  {'actual_k': 40, 'was_impossible': False}
# 6        1    23   4.0  4.152492  {'actual_k': 40, 'was_impossible': False}
# 7        1    24   3.0  3.514135  {'actual_k': 40, 'was_impossible': False}
# 8        1    27   2.0  3.438191  {'actual_k': 40, 'was_impossible': False}
# 9        1    31   3.0  3.803193  {'actual_k': 40, 'was_impossible': False}
# 10       1    33   4.0  3.666529  {'actual_k': 40, 'was_impossible': False}
# 11       1    36   2.0  2.346977   {'actual_k': 8, 'was_impossible': False}
# 12       1    39   4.0  3.408699  {'actual_k': 40, 'was_impossible': False}
# 13       1    44   5.0  3.363865  {'actual_k': 40, 'was_impossible': False}
# 14       1    47   4.0  3.758878  {'actual_k': 40, 'was_impossible': False}
# 15       1    49   3.0  3.472728  {'actual_k': 40, 'was_impossible': False}
# 16       1    51   4.0  3.692473  {'actual_k': 40, 'was_impossible': False}
# 17       1    53   3.0  3.431112  {'actual_k': 40, 'was_impossible': False}
# 18       1    54   3.0  3.415580  {'actual_k': 40, 'was_impossible': False}
# 19       1    56   4.0  4.009749  {'actual_k': 40, 'was_impossible': False}
# 20       1    60   5.0  4.157363  {'actual_k': 40, 'was_impossible': False}
# 21       1    61   4.0  3.922992  {'actual_k': 40, 'was_impossible': False}
# 22       1    62   3.0  3.533515  {'actual_k': 40, 'was_impossible': False}
# 23       1    64   5.0  4.324157  {'actual_k': 40, 'was_impossible': False}
# 24       1    65   4.0  3.579378  {'actual_k': 40, 'was_impossible': False}
# 25       1    67   3.0  3.163644  {'actual_k': 40, 'was_impossible': False}
# 26       1    69   3.0  3.865225  {'actual_k': 40, 'was_impossible': False}
# 27       1    70   3.0  3.694755  {'actual_k': 40, 'was_impossible': False}
# 28       1    72   4.0  3.328295  {'actual_k': 40, 'was_impossible': False}
# 29       1    73   3.0  3.519128  {'actual_k': 40, 'was_impossible': False}
# ...    ...   ...   ...       ...                                        ...
# 19970  454   418   3.0  2.883505  {'actual_k': 40, 'was_impossible': False}
# 19971  454   484   3.0  3.424256  {'actual_k': 40, 'was_impossible': False}
# 19972  454   487   4.0  3.395401  {'actual_k': 40, 'was_impossible': False}
# 19973  454   493   2.0  3.449066  {'actual_k': 40, 'was_impossible': False}
# 19974  454   633   2.0  3.408057  {'actual_k': 40, 'was_impossible': False}
# 19975  454  1063   4.0  3.124161  {'actual_k': 37, 'was_impossible': False}
# 19976  454  1299   2.0  2.284169   {'actual_k': 6, 'was_impossible': False}
# 19977  455   135   5.0  3.840801  {'actual_k': 40, 'was_impossible': False}
# 19978  455   282   3.0  3.670821  {'actual_k': 40, 'was_impossible': False}
# 19979  455   293   4.0  3.675647  {'actual_k': 40, 'was_impossible': False}
# 19980  455   629   3.0  3.172382  {'actual_k': 40, 'was_impossible': False}
# 19981  455   755   3.0  3.145144  {'actual_k': 40, 'was_impossible': False}
# 19982  456   175   3.0  3.511443  {'actual_k': 40, 'was_impossible': False}
# 19983  456   294   1.0  2.762455  {'actual_k': 40, 'was_impossible': False}
# 19984  456   715   3.0  3.421686  {'actual_k': 40, 'was_impossible': False}
# 19985  456   943   4.0  3.506665  {'actual_k': 31, 'was_impossible': False}
# 19986  457   182   4.0  4.586337  {'actual_k': 40, 'was_impossible': False}
# 19987  457   192   5.0  4.438706  {'actual_k': 40, 'was_impossible': False}
# 19988  457   366   4.0  3.913451  {'actual_k': 32, 'was_impossible': False}
# 19989  457   443   4.0  4.265664  {'actual_k': 40, 'was_impossible': False}
# 19990  457   636   4.0  3.756028  {'actual_k': 40, 'was_impossible': False}
# 19991  457   704   4.0  3.459260  {'actual_k': 17, 'was_impossible': False}
# 19992  457   708   4.0  3.871431  {'actual_k': 40, 'was_impossible': False}
# 19993  457   775   3.0  3.321254  {'actual_k': 19, 'was_impossible': False}
# 19994  458   144   4.0  3.766188  {'actual_k': 40, 'was_impossible': False}
# 19995  458   648   4.0  3.913156  {'actual_k': 40, 'was_impossible': False}
# 19996  458  1101   4.0  3.879986  {'actual_k': 40, 'was_impossible': False}
# 19997  459   934   3.0  2.853176  {'actual_k': 40, 'was_impossible': False}
# 19998  460    10   3.0  3.860369  {'actual_k': 40, 'was_impossible': False}
# 19999  462   682   5.0  3.711871  {'actual_k': 40, 'was_impossible': False}
#
# [20000 rows x 5 columns]

# %%
# The dump has been saved and we can now use it whenever we want.
#dump_obj = pickle.load(open('./dump_file', 'rb'))

# %%
#predictions = dump_obj['predictions']

#trainset = dump_obj['trainset']

#algo = dump_obj['algo']

#print('algo: {0}, k = {1}, min_k = {2}'.format(algo['name'], algo['k'], algo['min_k']))

# %%
# Let's build a pandas dataframe with all the predictions

def get_Iu(uid):
    """Return the number of items rated by given user
    
    Args:
        uid: The raw id of the user.
    Returns:
        The number of items rated by the user.
    """
    
    try:
        return len(trainset.ur[trainset.to_inner_uid(uid)])
    except ValueError:  # user was not part of the trainset
        return 0
    
def get_Ui(iid):
    """Return the number of users that have rated given item
    
    Args:
        iid: The raw id of the item.data.folds()
    Returns:
        The number of users that have rated the item.
    """
    
    try:
        return len(trainset.ir[trainset.to_inner_iid(iid)])
    except ValueError:  # item was not part of the trainset
        return 0

df = pd.DataFrame(predictions, columns=['user_id', 'item_id', 'ratings_ui', 'estimated_Ratings', 'details'])    
#df['Iu'] = df.user_id.apply(get_Iu)
#df['Ui'] = df.item_id.apply(get_Ui)
df['ERROR IN PREDICTION'] = abs(df.estimated_Ratings - df.ratings_ui)

# %%
df.head()
# Out:
#   user_id item_id  ratings_ui  estimated_Ratings  \
# 0       1       6         5.0           3.684493
# 1       1      10         3.0           3.830113
# 2       1      12         5.0           4.413642
# 3       1      14         5.0           4.156297
# 4       1      17         3.0           3.504539
#
#                                      details  ERROR IN PREDICTION
# 0  {'actual_k': 20, 'was_impossible': False}             1.315507
# 1  {'actual_k': 40, 'was_impossible': False}             0.830113
# 2  {'actual_k': 40, 'was_impossible': False}             0.586358
# 3  {'actual_k': 40, 'was_impossible': False}             0.843703
# 4  {'actual_k': 40, 'was_impossible': False}             0.504539

# %%
best_predictions = df.sort_values(by='ERROR IN PREDICTION')[:10]
worst_predictions = df.sort_values(by='ERROR IN PREDICTION')[-10:]

# %%
# Let's take a look at the best predictions of the algorithm
best_predictions
# Out:
#       user_id item_id  ratings_ui  estimated_Ratings  \
# 16373     330     172         5.0                5.0
# 13998     295     483         5.0                5.0
# 8008      181    1151         1.0                1.0
# 8005      181    1128         1.0                1.0
# 8003      181    1094         1.0                1.0
# 265         5     424         1.0                1.0
# 8001      181    1087         1.0                1.0
# 7993      181    1049         1.0                1.0
# 7991      181    1040         1.0                1.0
# 17369     350     174         5.0                5.0
#
#                                          details  ERROR IN PREDICTION
# 16373  {'actual_k': 40, 'was_impossible': False}                  0.0
# 13998  {'actual_k': 40, 'was_impossible': False}                  0.0
# 8008    {'actual_k': 4, 'was_impossible': False}                  0.0
# 8005    {'actual_k': 9, 'was_impossible': False}                  0.0
# 8003    {'actual_k': 8, 'was_impossible': False}                  0.0
# 265    {'actual_k': 13, 'was_impossible': False}                  0.0
# 8001    {'actual_k': 9, 'was_impossible': False}                  0.0
# 7993   {'actual_k': 19, 'was_impossible': False}                  0.0
# 7991   {'actual_k': 19, 'was_impossible': False}                  0.0
# 17369  {'actual_k': 40, 'was_impossible': False}                  0.0

# %% [markdown]
# It's interesting to note that these perfect predictions are actually lucky shots: $|U_i|$ is always very small, meaning that very few users have rated the target item. This implies that the set of neighbors is very small (see the ``actual_k`` field)... And, it just happens that all the ratings from the neighbors are the same (and mostly, are equal to that of the target user).
#
# This may be a bit surprising but these lucky shots are actually very important to the accuracy of the algorithm... Try running the same algorithm with a value of ``min_k`` equal to $10$. This means that if there are less than $10$ neighbors, the prediction is set to the mean of all ratings. You'll see your accuracy decrease!

# %%
# Now, let's look at the prediction with the biggest error
worst_predictions
# Out:
#       user_id item_id  ratings_ui  estimated_Ratings  \
# 157         2     315         1.0           4.499064
# 13972     295     183         1.0           4.551218
# 15290     312     157         1.0           4.557994
# 9514      212     180         1.0           4.588900
# 9289      206     895         5.0           1.410249
# 7861      181      25         5.0           1.306411
# 7390      167     169         1.0           4.729330
# 15306     312     265         1.0           4.761210
# 15286     312     144         1.0           4.936065
# 19140     405     575         5.0           1.000000
#
#                                          details  ERROR IN PREDICTION
# 157    {'actual_k': 40, 'was_impossible': False}             3.499064
# 13972  {'actual_k': 40, 'was_impossible': False}             3.551218
# 15290  {'actual_k': 40, 'was_impossible': False}             3.557994
# 9514   {'actual_k': 40, 'was_impossible': False}             3.588900
# 9289   {'actual_k': 40, 'was_impossible': False}             3.589751
# 7861   {'actual_k': 40, 'was_impossible': False}             3.693589
# 7390   {'actual_k': 40, 'was_impossible': False}             3.729330
# 15306  {'actual_k': 40, 'was_impossible': False}             3.761210
# 15286  {'actual_k': 40, 'was_impossible': False}             3.936065
# 19140  {'actual_k': 36, 'was_impossible': False}             4.000000

# %% [markdown]
# Let's focus first on the last two predictions. Well, we can't do much about them. We should have predicted $5$, but the only available neighbor had a rating of $1$, so we were screwed. The only way to avoid this kind of errors would be to increase the ``min_k`` parameter, but it would actually worsen the accuracy (see note above).
#
# How about the other ones? It seems that for each prediction, the users are some kind of outsiders: they rated their item with a rating of $1$ when the most of the ratings for the item where high (or inversely, rated a *bad* item with a rating of $5$). See the plot below as an illustration for the first rating.
#
# These are situations where baseline estimates would be quite helpful, in order to deal with highly biased users (and items).

# %%
from collections import Counter

import matplotlib.pyplot as plt
import matplotlib
# %matplotlib notebook
matplotlib.style.use('ggplot')

counter = Counter([r for (_, r) in trainset.ir[trainset.to_inner_iid('302')]])
pd.DataFrame.from_dict(counter, orient='index').plot(kind='bar', legend=False)
plt.xlabel('Rating value')
plt.ylabel('Number of users')
plt.title('Number of users having rated item 302')
# Out:
# <img src="data:image/png;base64,..." width="640">
